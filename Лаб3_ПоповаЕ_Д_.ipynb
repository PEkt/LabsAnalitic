# %% [markdown]
# <a href="https://colab.research.google.com/github/PEkt/LabsAnalitic/blob/main/%D0%9B%D0%B0%D0%B13_%D0%9F%D0%BE%D0%BF%D0%BE%D0%B2%D0%B0%D0%95_%D0%94_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Задание 1

# %% [markdown]
# Напишите программу для численного вычисления определённого интеграла с помощью средств SciPy. Сравните результаты вычисления различными функциями интегрирования с точным решением.

# %%
from scipy import *
from scipy import integrate
from scipy.integrate import *
import math
import numpy as np
from numpy.lib.scimath import *
from scipy.integrate import simps
import sympy as sy

# %%
def f(x):
  return 1 / math.sin(x)
integrate.quad(f, 1.01, 0.5)
# Out:
# (-0.7724154756086484, 8.575534455975125e-15)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5c5d1e83-8987-4e5e-b07a-af814b82b68d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5c5d1e83-8987-4e5e-b07a-af814b82b68d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving l8HkycXaPmQ.jpg to l8HkycXaPmQ.jpg

# %%
from io import BytesIO
from PIL import Image
im = Image.open(BytesIO(uploaded['l8HkycXaPmQ.jpg']))
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2560x1226 at 0x7F6513248A90>

# %%
ar = math.log1p(math.tan(0.25)/math.tan(0.005))
print(ar)
# Out:
# 3.9525497629039155

# %% [markdown]
# # Задание 2

# %% [markdown]
# Напишите программу для численного решения обыкновенного дифференциального уравнения с заданным начальным условием с помощью средств SciPy. Сравните результат вычисления
# с точным решением. Нарисуйте графики точного и численного решений, а также относительной ошибки численного решения.

# %%
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %%
def F(a, t, b, c):
    dudt = a[1]
    dvdt = -b*a[1] - c*a[0]
    return [dudt, dvdt]

b = 0
c = 4
y0 = [1, 1]
t = np.linspace(-10, 10, 1000)
aol = odeint(F, y0, t, args=(b, c))
y1 = aol[:,0]
y2 = aol[:,1]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set(title='Тригонометрическая функция')
ax.set_xlabel('t')
ax.set_ylabel('y')
ax.plot(t, y1, color = '#ff2b44', linewidth = 1)
ax.plot(t, y2, color = '#0c1a99', linewidth = 1)
legend = ax.legend(['y1', 'y2'], loc='upper left')
legend.get_frame().set_facecolor('w')
plt.grid()
plt.show()
